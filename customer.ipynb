# %% [markdown]
# ### Import libraries

# %%
# Standard library imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Scikit-learn imports for preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# Fake data
from faker import Faker
fake = Faker()

# %% [markdown]
# ### Create fake data

# %%
# We will create some fake data using numpy
num_companies = 10000
num_products = 30

# Create random data.
data = np.random.randint(0, 51, size=(num_companies, num_products))

# Create the dataframe
df = pd.DataFrame(data,
                  index=[f"Company{i+1}" for i in range(num_companies)],
                  columns=[f"product_{i+1}" for i in range(num_products)])

df.head()
# Out:
#           product_1  product_2  product_3  product_4  product_5  product_6
# Company1         14         33         27         19         35         32  \
# Company2         21         26         47         31         34         48
# Company3         21         18         31         48         33         37
# Company4         19         32         47         40         12         29
# Company5         23         48         33         38         18         30
#
#           product_7  product_8  product_9  product_10  ...  product_21
# Company1          7         37         32          48  ...          21  \
# Company2         47         10         23          45  ...          37
# Company3         38         37          7          13  ...           2
# Company4         32         44         43          50  ...           5
# Company5         47         17         44          12  ...          25
#
#           product_22  product_23  product_24  product_25  product_26
# Company1           4           8           6           3          26  \
# Company2           8          44          18          12          37
# Company3           2          14          38          31          15
# Company4          40          11          31           3          41
# Company5          33          34          37          45          21
#
#           product_27  product_28  product_29  product_30
# Company1          27          49          29          28
# Company2           7          45           8          45
# Company3           9          46           4          23
# Company4          16          18          49          44
# Company5          49          30          15          32
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (10000, 30)

# %% [markdown]
# #### Add faker

# %%
# Generate 10 unique industries that we can assign to the companies

unique_industries = [fake.bs() for _ in range(10)]
df['Industry'] = [fake.random_element(elements=unique_industries) for _ in range(num_companies)]

# %%
df['Company Size'] = [fake.random_element(elements=('Small', 'Medium', 'Large')) for _ in range(num_companies)]
df['Region'] = [fake.country() for _ in range(num_companies)]

# %%
df.head()
# Out:
#           product_1  product_2  product_3  product_4  product_5  product_6
# Company1         14         33         27         19         35         32  \
# Company2         21         26         47         31         34         48
# Company3         21         18         31         48         33         37
# Company4         19         32         47         40         12         29
# Company5         23         48         33         38         18         30
#
#           product_7  product_8  product_9  product_10  ...  product_24
# Company1          7         37         32          48  ...           6  \
# Company2         47         10         23          45  ...          18
# Company3         38         37          7          13  ...          38
# Company4         32         44         43          50  ...          31
# Company5         47         17         44          12  ...          37
#
#           product_25  product_26  product_27  product_28  product_29
# Company1           3          26          27          49          29  \
# Company2          12          37           7          45           8
# Company3          31          15           9          46           4
# Company4           3          41          16          18          49
# Company5          45          21          49          30          15
#
#           product_30                            Industry  Company Size
# Company1          28     syndicate best-of-breed schemas         Small  \
# Company2          45  synergize turn-key functionalities         Large
# Company3          23  scale mission-critical initiatives        Medium
# Company4          44     syndicate best-of-breed schemas         Large
# Company5          32  synergize turn-key functionalities        Medium
#
#                              Region
# Company1                    Tunisia
# Company2                      Qatar
# Company3                      Haiti
# Company4                     Mexico
# Company5  Bouvet Island (Bouvetoya)
#
# [5 rows x 33 columns]

# %%
# Move the last three columns to the front
cols = df.columns.tolist() # Create a list of all of the columns
cols = cols[-3:] + cols[:-3] # Reorder the columns so that the last three are first
df = df[cols] # Reassign the dataframe to have the new column order
df.head()
# Out:
#                                     Industry Company Size
# Company1     syndicate best-of-breed schemas        Small  \
# Company2  synergize turn-key functionalities        Large
# Company3  scale mission-critical initiatives       Medium
# Company4     syndicate best-of-breed schemas        Large
# Company5  synergize turn-key functionalities       Medium
#
#                              Region  product_1  product_2  product_3
# Company1                    Tunisia         14         33         27  \
# Company2                      Qatar         21         26         47
# Company3                      Haiti         21         18         31
# Company4                     Mexico         19         32         47
# Company5  Bouvet Island (Bouvetoya)         23         48         33
#
#           product_4  product_5  product_6  product_7  ...  product_21
# Company1         19         35         32          7  ...          21  \
# Company2         31         34         48         47  ...          37
# Company3         48         33         37         38  ...           2
# Company4         40         12         29         32  ...           5
# Company5         38         18         30         47  ...          25
#
#           product_22  product_23  product_24  product_25  product_26
# Company1           4           8           6           3          26  \
# Company2           8          44          18          12          37
# Company3           2          14          38          31          15
# Company4          40          11          31           3          41
# Company5          33          34          37          45          21
#
#           product_27  product_28  product_29  product_30
# Company1          27          49          29          28
# Company2           7          45           8          45
# Company3           9          46           4          23
# Company4          16          18          49          44
# Company5          49          30          15          32
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Add target variable

# %%
df['purchased_new_sku'] = np.random.randint(0, 2, size=num_companies)
df.head()
# Out:
#                                     Industry Company Size
# Company1     syndicate best-of-breed schemas        Small  \
# Company2  synergize turn-key functionalities        Large
# Company3  scale mission-critical initiatives       Medium
# Company4     syndicate best-of-breed schemas        Large
# Company5  synergize turn-key functionalities       Medium
#
#                              Region  product_1  product_2  product_3
# Company1                    Tunisia         14         33         27  \
# Company2                      Qatar         21         26         47
# Company3                      Haiti         21         18         31
# Company4                     Mexico         19         32         47
# Company5  Bouvet Island (Bouvetoya)         23         48         33
#
#           product_4  product_5  product_6  product_7  ...  product_22
# Company1         19         35         32          7  ...           4  \
# Company2         31         34         48         47  ...           8
# Company3         48         33         37         38  ...           2
# Company4         40         12         29         32  ...          40
# Company5         38         18         30         47  ...          33
#
#           product_23  product_24  product_25  product_26  product_27
# Company1           8           6           3          26          27  \
# Company2          44          18          12          37           7
# Company3          14          38          31          15           9
# Company4          11          31           3          41          16
# Company5          34          37          45          21          49
#
#           product_28  product_29  product_30  purchased_new_sku
# Company1          49          29          28                  0
# Company2          45           8          45                  1
# Company3          46           4          23                  1
# Company4          18          49          44                  1
# Company5          30          15          32                  0
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Create weights

# %%
# Create weights for each product
final_weights = [2, 1, 5, 3, 10, 10, 5, 8, 9, 3, 5, 5, 5, 5, 5, 6, 10, 1, 1, 3, 2, 10, 9, 8, 7, 6, 5, 4, 3, 2]
assert len(final_weights) == num_products
if len(final_weights) != num_products:
    raise ValueError("Number of weights must match number of products")
else:
    print("Weights are correct")
# Out:
# Weights are correct

# %% [markdown]
# #### Calculate weighted score for each company

# %%
# Create a column for the total weight of each company
df['weighted_score'] = df.iloc[:, 3:33].dot(final_weights)

# %%
scaler = MinMaxScaler(feature_range=(0, 100))

# %%
normalized_score = scaler.fit_transform(df[['weighted_score']])

# %%
# Create a column for the normalized score
df['normalized_score'] = normalized_score.round(2)

# %%
df.head()
# Out:
#                                     Industry Company Size
# Company1     syndicate best-of-breed schemas        Small  \
# Company2  synergize turn-key functionalities        Large
# Company3  scale mission-critical initiatives       Medium
# Company4     syndicate best-of-breed schemas        Large
# Company5  synergize turn-key functionalities       Medium
#
#                              Region  product_1  product_2  product_3
# Company1                    Tunisia         14         33         27  \
# Company2                      Qatar         21         26         47
# Company3                      Haiti         21         18         31
# Company4                     Mexico         19         32         47
# Company5  Bouvet Island (Bouvetoya)         23         48         33
#
#           product_4  product_5  product_6  product_7  ...  product_24
# Company1         19         35         32          7  ...           6  \
# Company2         31         34         48         47  ...          18
# Company3         48         33         37         38  ...          38
# Company4         40         12         29         32  ...          31
# Company5         38         18         30         47  ...          37
#
#           product_25  product_26  product_27  product_28  product_29
# Company1           3          26          27          49          29  \
# Company2          12          37           7          45           8
# Company3          31          15           9          46           4
# Company4           3          41          16          18          49
# Company5          45          21          49          30          15
#
#           product_30  purchased_new_sku  weighted_score  normalized_score
# Company1          28                  0            3447             34.38
# Company2          45                  1            4204             55.33
# Company3          23                  1            3959             48.55
# Company4          44                  1            4685             68.63
# Company5          32                  0            4720             69.60
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Build a model

# %% [markdown]
# We are skipping EDA because the data is ready to go for modelling.
